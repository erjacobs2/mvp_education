# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#import csv
df = pd.read_csv('Cleaned_Data.csv')
df.head()
# Out:
#     PRIMARY_KEY    STATE Region  YEAR  ENROLL  TOTAL_REVENUE  \
# 0  1993_ALABAMA  ALABAMA  South  1993  727716        2827391
# 1  1994_ALABAMA  ALABAMA  South  1994  730004        2970223
# 2  1995_ALABAMA  ALABAMA  South  1995  727480        3367437
# 3  1996_ALABAMA  ALABAMA  South  1996  735912        3365113
# 4  1997_ALABAMA  ALABAMA  South  1997  737386        3981788
#
#    TOTAL_REVENUE_PS  FEDERAL_REVENUE  FEDERAL_REVENUE_PS  STATE_REVENUE  \
# 0          4.172101           331409            0.489027        1729295
# 1          4.375645           331823            0.488832        1850894
# 2          4.905868           328957            0.479243        2161366
# 3          4.898393           334858            0.487433        2138717
# 4          5.763349           376200            0.544522        2498847
#
#           ...           GRADES_4_G  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  \
# 0         ...                57497       60004        39900        470775
# ...

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

# print("Shape: ", X.shape, math_4.shape)
X = df.TOTAL_REVENUE.values.reshape(-1, 1)
y = df.AVG_MATH_4_SCORE.values.reshape(-1, 1)

south = df.loc[df['Region'] == 'South']
west = df.loc[df['Region'] == 'West']
northeast = df.loc[df['Region'] == 'Northeast']
midwest = df.loc[df['Region'] == 'Midwest']

X_south = south.TOTAL_REVENUE.values.reshape(-1, 1)
math4south = south.AVG_MATH_4_SCORE.values.reshape(-1, 1)

X_west = west.TOTAL_REVENUE.values.reshape(-1, 1)
math4west = west.AVG_MATH_4_SCORE.values.reshape(-1, 1)

X_northeast = northeast.TOTAL_REVENUE.values.reshape(-1, 1)
math4ne = northeast.AVG_MATH_4_SCORE.values.reshape(-1, 1)

X_midwest = midwest.TOTAL_REVENUE.values.reshape(-1, 1)
math4mw = midwest.AVG_MATH_4_SCORE.values.reshape(-1, 1)

# %%
plt.scatter(X_south, math4south)
# blue
plt.scatter(X_west, math4west)
# orange
plt.scatter(X_northeast, math4ne)
# green
plt.scatter(X_midwest, math4mw) 
# red

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[1.37532571e-07]]
# y-axis intercept:  [231.01093285]

# %%
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[465650]]
# Max X Value: [[74626928]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
s = plt.scatter(X_south, math4south, c='blue')
w = plt.scatter(X_west, math4west, c='orange')
ne = plt.scatter(X_northeast, math4ne, c='green')
mw = plt.scatter(X_midwest, math4mw, c='red')

plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='black')

plt.xlabel('Total Revenue (Tens of Millions)')
plt.ylabel('Avg. 4th Grade Math Scores')
plt.title('Revenue vs. 4th Grade Math Scores')
plt.show()

# %%
plt.savefig("Images/Math4.png")

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

# print("Shape: ", X.shape, math_4.shape)
X = df.TOTAL_REVENUE.values.reshape(-1, 1)
y = df.AVG_MATH_8_SCORE.values.reshape(-1, 1)

south = df.loc[df['Region'] == 'South']
west = df.loc[df['Region'] == 'West']
northeast = df.loc[df['Region'] == 'Northeast']
midwest = df.loc[df['Region'] == 'Midwest']

X_south = south.TOTAL_REVENUE.values.reshape(-1, 1)
math8south = south.AVG_MATH_8_SCORE.values.reshape(-1, 1)

X_west = west.TOTAL_REVENUE.values.reshape(-1, 1)
math8west = west.AVG_MATH_8_SCORE.values.reshape(-1, 1)

X_northeast = northeast.TOTAL_REVENUE.values.reshape(-1, 1)
math8ne = northeast.AVG_MATH_8_SCORE.values.reshape(-1, 1)

X_midwest = midwest.TOTAL_REVENUE.values.reshape(-1, 1)
math8mw = midwest.AVG_MATH_8_SCORE.values.reshape(-1, 1)

# %%
s = plt.scatter(X_south, math8south, c='blue')
w = plt.scatter(X_west, math8west, c='orange')
ne = plt.scatter(X_northeast, math8ne, c='green')
mw = plt.scatter(X_midwest, math8mw, c='red')

plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='black')

plt.xlabel('Total Revenue (Tens of Millions)')
plt.ylabel('Avg. 8th Grade Math Scores')
plt.title('Revenue vs. 8th Grade Math Scores')
plt.show()

# %%
plt.savefig("Images/Math8.png")

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

# print("Shape: ", X.shape, math_4.shape)
X = df.TOTAL_REVENUE.values.reshape(-1, 1)
y = df.AVG_READING_8_SCORE.values.reshape(-1, 1)

south = df.loc[df['Region'] == 'South']
west = df.loc[df['Region'] == 'West']
northeast = df.loc[df['Region'] == 'Northeast']
midwest = df.loc[df['Region'] == 'Midwest']

X_south = south.TOTAL_REVENUE.values.reshape(-1, 1)
reading8south = south.AVG_READING_8_SCORE.values.reshape(-1, 1)

X_west = west.TOTAL_REVENUE.values.reshape(-1, 1)
reading8west = west.AVG_READING_8_SCORE.values.reshape(-1, 1)

X_northeast = northeast.TOTAL_REVENUE.values.reshape(-1, 1)
reading8ne = northeast.AVG_READING_8_SCORE.values.reshape(-1, 1)

X_midwest = midwest.TOTAL_REVENUE.values.reshape(-1, 1)
reading8mw = midwest.AVG_READING_8_SCORE.values.reshape(-1, 1)

# %%
s = plt.scatter(X_south, reading8south, c='blue')
w = plt.scatter(X_west, reading8west, c='orange')
ne = plt.scatter(X_northeast, reading8ne, c='green')
mw = plt.scatter(X_midwest, reading8mw, c='red')

plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='black')

plt.xlabel('Total Revenue (Tens of Millions)')
plt.ylabel('Avg. 8th Grade Reading Scores')
plt.title('Revenue vs. 8th Grade Reading Scores')
plt.show()

# %%
plt.savefig("Images/Reading8.png")

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

# print("Shape: ", X.shape, math_4.shape)
X = df.TOTAL_REVENUE.values.reshape(-1, 1)
y = df.AVG_READING_4_SCORE.values.reshape(-1, 1)

south = df.loc[df['Region'] == 'South']
west = df.loc[df['Region'] == 'West']
northeast = df.loc[df['Region'] == 'Northeast']
midwest = df.loc[df['Region'] == 'Midwest']

X_south = south.TOTAL_REVENUE.values.reshape(-1, 1)
reading4south = south.AVG_READING_4_SCORE.values.reshape(-1, 1)

X_west = west.TOTAL_REVENUE.values.reshape(-1, 1)
reading4west = west.AVG_READING_4_SCORE.values.reshape(-1, 1)

X_northeast = northeast.TOTAL_REVENUE.values.reshape(-1, 1)
reading4ne = northeast.AVG_READING_4_SCORE.values.reshape(-1, 1)

X_midwest = midwest.TOTAL_REVENUE.values.reshape(-1, 1)
reading4mw = midwest.AVG_READING_4_SCORE.values.reshape(-1, 1)

# %%
s = plt.scatter(X_south, reading4south, c='blue')
w = plt.scatter(X_west, reading4west, c='orange')
ne = plt.scatter(X_northeast, reading4ne, c='green')
mw = plt.scatter(X_midwest, reading4mw, c='red')

plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='black')

plt.xlabel('Total Revenue (Tens of Millions)')
plt.ylabel('Avg. 4th Grade Reading Scores')
plt.title('Revenue vs. 4th Grade Reading Scores')
plt.show()
plt.savefig("Images/Reading4.png")
